# %%
# main.py
from utils.data_preprocessing import dualpi2_pre_process_extract, trim_df
from utils.eval_exp_gen import gen_eval_exp_pool
from utils.train_exp_gen import gen_train_exp_pool
from utils.config import columns_to_use


# Step 1: Preprocess data
df = dualpi2_pre_process_extract("./Data/vmware/kernel_data_1_dualpi2_8Mbps_10ms_ecn_udp.txt")


print(df[columns_to_use[0]].value_counts())
print(df[columns_to_use[3]].describe())
print("queue delay median",df[columns_to_use[3]].median())


# Step 2: Trim the DataFrame (if needed)
# df = trim_df(df, 0.2)

# Step 3: Generate training and evaluation experience pools
gen_train_exp_pool(df,'vmware_udp_exp_pool_l4s_train.pkl', train_exp_percent=0.2)
gen_eval_exp_pool(df,'vmware_udp_exp_pool_l4s_eval.pkl', eval_exp_percent=1)


df[columns_to_use[0]].value_counts()
df['dequeue_action'].value_counts()
# Out:
# queue_type
# 1    110178
# 0     40678
# Name: count, dtype: int64
# count    1.508560e+05
# mean     3.864149e+04
# std      3.635003e+04
# min      0.000000e+00
# 25%      2.000000e+04
# 50%      3.000000e+04
# 75%      4.000000e+04
# max      1.170000e+06
# Name: current_queue_delay, dtype: float64
# queue delay median 30000.0
# len(df) 150856
# Training experience pool saved at: vmware_udp_exp_pool_l4s_train.pkl
# len(actions) 3695
# Evaluation experience pool saved at: vmware_udp_exp_pool_l4s_eval.pkl
# len(actions) 150856
# dequeue_action
# 0    149219
# 1      1020
# 2       617
# Name: count, dtype: int64

# %%
first_indices_dict = df['dequeue_action'].drop_duplicates().to_dict()
print(first_indices_dict)
# Out:
# {0: 0, 760: 1, 8707: 2}

# %%
# main.py
from utils.data_preprocessing import dualpi2_pre_process_extract, trim_df
from utils.eval_exp_gen import gen_eval_exp_pool
from utils.train_exp_gen import gen_train_exp_pool
from utils.config import columns_to_use


# Step 1: Preprocess data
df = dualpi2_pre_process_extract("./Data/vmware/kernel_data_1_dualpi2_8Mbps_10ms_ecn_tcp.txt")

print(df[columns_to_use[0]].value_counts())
print(df[columns_to_use[3]].describe())
print("queue delay median",df[columns_to_use[3]].median())


# Step 2: Trim the DataFrame (if needed)
# df = trim_df(df, 0.2)

# Step 3: Generate training and evaluation experience pools
gen_train_exp_pool(df,'vmware_tcp_exp_pool_l4s_train.pkl', train_exp_percent=0.2)
gen_eval_exp_pool(df,'vmware_tcp_exp_pool_l4s_eval.pkl', eval_exp_percent=1)

df[columns_to_use[0]].value_counts()
df['dequeue_action'].value_counts()
# Out:
# queue_type
# 0    121993
# Name: count, dtype: int64
# count    121993.000000
# mean      42090.611756
# std       39270.535797
# min           0.000000
# 25%       10000.000000
# 50%       30000.000000
# 75%       60000.000000
# max      260000.000000
# Name: current_queue_delay, dtype: float64
# queue delay median 30000.0
# len(df) 121993
# Training experience pool saved at: vmware_tcp_exp_pool_l4s_train.pkl
# len(actions) 2530
# Evaluation experience pool saved at: vmware_tcp_exp_pool_l4s_eval.pkl
# len(actions) 121993
# dequeue_action
# 0    120146
# 1      1565
# 2       282
# Name: count, dtype: int64

# %%
first_indices_dict = df['dequeue_action'].drop_duplicates().to_dict()
print(first_indices_dict)
# Out:
# {0: 0, 988: 1, 1655: 2}

# %%
# main.py
from utils.data_preprocessing import dualpi2_pre_process_extract, trim_df
from utils.eval_exp_gen import gen_eval_exp_pool
from utils.train_exp_gen import gen_train_exp_pool
from utils.config import columns_to_use


# Step 1: Preprocess data
df = dualpi2_pre_process_extract("./Data/vbox/kernel_data_1_dualpi2_8Mbps_10ms_ecn_udp.txt")

print(df[columns_to_use[0]].value_counts())
print(df[columns_to_use[3]].describe())
print("queue delay median",df[columns_to_use[3]].median())


# Step 2: Trim the DataFrame (if needed)
# df = trim_df(df, 0.2)

# Step 3: Generate training and evaluation experience pools
gen_train_exp_pool(df,'vbox_udp_exp_pool_l4s_train.pkl', train_exp_percent=1)
gen_eval_exp_pool(df,'vbox_udp_exp_pool_l4s_eval.pkl', eval_exp_percent=1)

df[columns_to_use[0]].value_counts()
df['dequeue_action'].value_counts()
# Out:
# queue_type
# 1    102033
# 0     45714
# Name: count, dtype: int64
# count    147747.000000
# mean      47075.947397
# std       46812.880679
# min           0.000000
# 25%       10000.000000
# 50%       40000.000000
# 75%       70000.000000
# max      320000.000000
# Name: current_queue_delay, dtype: float64
# queue delay median 40000.0
# len(df) 147747
# Training experience pool saved at: vbox_udp_exp_pool_l4s_train.pkl
# len(actions) 4020
# Evaluation experience pool saved at: vbox_udp_exp_pool_l4s_eval.pkl
# len(actions) 147747
# dequeue_action
# 0    147308
# 1       254
# 2       185
# Name: count, dtype: int64

# %%
first_indices_dict = df['dequeue_action'].drop_duplicates().to_dict()
print(first_indices_dict)
# Out:
# {0: 0, 6722: 2, 6957: 1}

# %%
# main.py
from utils.data_preprocessing import dualpi2_pre_process_extract, trim_df
from utils.eval_exp_gen import gen_eval_exp_pool
from utils.train_exp_gen import gen_train_exp_pool
from utils.config import columns_to_use


# Step 1: Preprocess data
df = dualpi2_pre_process_extract("./Data/vbox/kernel_data_1_dualpi2_8Mbps_10ms_ecn_tcp.txt")

print(df[columns_to_use[0]].value_counts())
print(df[columns_to_use[3]].describe())
print("queue delay median",df[columns_to_use[3]].median())


# Step 2: Trim the DataFrame (if needed)
# df = trim_df(df, 0.2)

# Step 3: Generate training and evaluation experience pools
gen_train_exp_pool(df,'vbox_tcp_exp_pool_l4s_train.pkl', train_exp_percent=1)
gen_eval_exp_pool(df,'vbox_tcp_exp_pool_l4s_eval.pkl', eval_exp_percent=1)

df[columns_to_use[0]].value_counts()
df['dequeue_action'].value_counts()
# Out:
# queue_type
# 0    120719
# Name: count, dtype: int64
# count    120719.000000
# mean      68215.856659
# std       56424.948743
# min           0.000000
# 25%       10000.000000
# 50%       70000.000000
# 75%      110000.000000
# max      310000.000000
# Name: current_queue_delay, dtype: float64
# queue delay median 70000.0
# len(df) 120719
# Training experience pool saved at: vbox_tcp_exp_pool_l4s_train.pkl
# len(actions) 4680
# Evaluation experience pool saved at: vbox_tcp_exp_pool_l4s_eval.pkl
# len(actions) 120719
# dequeue_action
# 0    120050
# 1       443
# 2       226
# Name: count, dtype: int64

# %%
first_indices_dict = df['dequeue_action'].drop_duplicates().to_dict()
print(first_indices_dict)
# Out:
# {0: 0, 3148: 2, 3236: 1}
